# %% [markdown]
# # COVID-19

# %%
import pandas as pd
import seaborn as sns; sns.set()

# %%
death = pd.read_csv('./data/deaths_cumulative_daily.csv')
death['Date'] = pd.to_datetime(death['Date'], format='%Y/%m/%d')
death
# Out:
#           Date    ALL  Hokkaido  Aomori  Iwate  Miyagi  Akita  Yamagata  \
# 0   2020-05-09    613        48       0      0       1      0         0
# 1   2020-05-10    621        51       0      0       1      0         0
# 2   2020-05-11    643        56       0      0       1      0         0
# 3   2020-05-12    668        62       0      0       1      0         0
# 4   2020-05-13    687        68       0      0       1      0         0
# ..         ...    ...       ...     ...    ...     ...    ...       ...
# 596 2021-12-26  18379      1474      38     53     118     27        56
# 597 2021-12-27  18379      1474      38     53     118     27        56
# 598 2021-12-28  18381      1474      38     53     118     27        56
# 599 2021-12-29  18385      1475      38     53     118     27        56
# 600 2021-12-30  18385      1475      38     53     118     27        56
#
#      Fukushima  Ibaraki  ...  Ehime  Kochi  Fukuoka  Saga  Nagasaki  Kumamoto  \
# ...

# %% [markdown]
# ## Visualize Cumulative death toll

# %%
sns.lineplot(data=death, x='Date', y='ALL')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='ALL'>

# %% [markdown]
# ## Visualize Number of deaths on the day

# %%
sns.lineplot(
    data=pd.concat([death['Date'], death['ALL'].diff()], axis=1),
    x='Date',
    y='ALL'
)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='ALL'>

# %%
positive = pd.read_csv('./data/confirmed_cases_cumulative_daily.csv')
positive['Date'] = pd.to_datetime(positive['Date'], format='%Y/%m/%d')
positive
# Out:
#           Date      ALL  Hokkaido  Aomori  Iwate  Miyagi  Akita  Yamagata  \
# 0   2020-05-09    15581       934      27      0      88     16        69
# 1   2020-05-10    15630       945      27      0      88     16        69
# 2   2020-05-11    15706       954      27      0      88     16        69
# 3   2020-05-12    15854       966      27      0      88     16        69
# 4   2020-05-13    15908       979      27      0      88     16        69
# ..         ...      ...       ...     ...    ...     ...    ...       ...
# 596 2021-12-26  1726602     61391    5901   3487   16288   1934      3606
# 597 2021-12-27  1726770     61402    5901   3488   16288   1934      3606
# 598 2021-12-28  1727063     61422    5901   3488   16289   1934      3606
# 599 2021-12-29  1727426     61448    5901   3488   16290   1934      3607
# 600 2021-12-30  1727837     61480    5901   3490   16290   1934      3607
#
#      Fukushima  Ibaraki  ...  Ehime  Kochi  Fukuoka  Saga  Nagasaki  Kumamoto  \
# ...

# %% [markdown]
# ## Visualize Cumulative number of infected people

# %%
sns.lineplot(data=positive, x='Date', y='ALL')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='ALL'>

# %%
sns.lineplot(
    data=pd.concat([positive['Date'], positive['ALL'].diff()], axis=1),
    x='Date',
    y='ALL'
)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='ALL'>
